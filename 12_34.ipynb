# %% [markdown]
# <a href="https://colab.research.google.com/github/jhildebrand22/HW-PS353/blob/main/12_34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install whit_phys_util 1> \dev\null

# %%
import whit_phys_util as buc
from numpy import *
import matplotlib.pyplot as plt

# %%
repo = buc.local_repository('https://github.com/jhildebrand22/HW-PS353')
# Out:
# Repository exists at this location. Pulling changes from GitHub.

# %%
def sin_map(r,x):
  return r*sin(pi*x)

# %%
def x_t(r):  
  x_new = [x_0]
  for i in range(t_steps):
    x_new.append(sin_map(r,x_new[i]))
  x_stable = x_new[99:199]
  return x_stable

# %%
t_steps = 200
t_vals = 1001
x_0 = 0.1
r = linspace(0.6,1,t_vals)
t = linspace(100,200,t_vals)

# %%
x_array = []
for r_i in r:
  x_array.append(x_t(r_i))

# %%
x_t(0.89)[0:20]
# Out:
# [0.8628625718795867,
#  0.37168628811154386,
#  0.8186626554216314,
#  0.48003877306124926,
#  0.8882505888415346,
#  0.30607438203674325,
#  0.7298764080717527,
#  0.6678273280025426,
#  0.769134874379169,
#  0.5903798325051887,
#  0.8543644781754762,
#  0.3931408119656926,
#  0.8403177891420733,
#  0.4279819193660944,
#  0.8673175776488115,
#  0.360332241839965,
#  0.8056911673270498,
#  0.5101723817928844,
#  0.8895455688447365,
#  0.30267192208631416]

# %%
fig,ax = plt.subplots()
ax.plot(r,x_array,'.',markersize = 2,color='g')
ax.set_xlabel('r')
ax.set_ylabel('x');
